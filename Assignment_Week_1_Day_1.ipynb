# %% [markdown]
# <a href="https://colab.research.google.com/github/harshadsavle/alma-X/blob/main/Assignment_Week_1_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 1. What is the value of the function (x − 1) (x − 2)^2 at its maxima?
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Q1 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q1 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q1 3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Compute the Jacobian of the following transformation.
#
#  ![image.png](data:image/png;base64,...)
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Q2 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3. Given v = i - 2j + 2k and u = 4i - 3k, Find
# ## --the component of v in the direction of u,
#
# ## --the projection of v in the direction of u,
#
# ## --the resolution of v into components parallel and perpendicular to u.
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Q3 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q3 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Find a vector that is orthogonal to the plane containing the points P=(3,0,1), Q=(4,−2,1) and R=(5,3,−1).
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Q4 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 5. How do you choose a machine learning algorithm for a problem statement?
# ## Explain Briefly.

# %% [markdown]
#  ![Q5 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q5 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q5 3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 6. What is Semi- Supervised Learning and why is it so important?

# %% [markdown]
#  ![Q6 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q6 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 7. Why we can’t do a classification problem using Regression?

# %% [markdown]
# ![Q7 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 8. How do you treat heteroscedasticity in regression? What causes Heteroscedasticity and how to fix it?

# %% [markdown]
# ![Q8 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Q8 2.jpg](data:image/jpeg;base64,...)
